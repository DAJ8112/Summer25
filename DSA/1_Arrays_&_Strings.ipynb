# %% [markdown]
# ![Screenshot 2025-06-10 at 11.16.46 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### **Arrays**

# %%
A = [1, 2, 3]

print(A)
# Out:
# [1, 2, 3]

# %%
# Append - Insert element at end of array - On Average: O(1)
A.append(4)

print(A)
# Out:
# [1, 2, 3, 4]

# %%
# Pop - Deleting element at end of array - O(1)
A.pop()

print(A)
# Out:
# [1, 2, 3]

# %%
# Insert (not at end of Array) - O(n)
A.insert(2, 8)

print(A)
# Out:
# [1, 2, 8, 3]

# %%
# Modify an element - O(1)

A[0] = 7

print(A)
# Out:
# [7, 2, 8, 3]

# %%
# Accessing an element at given index - O(1)

print(A[2])
# Out:
# 8

# %%
# Checking if array has an element - O(n)

if 6 in A:
    print(True)
else:
    print(False)
# Out:
# False

# %%
# Check the length - O(1)

print(len(A))
# Out:
# 4

# %% [markdown]
# ### **Strings**

# %%
# Append to end of string - O(n)

s = 'hello'

b = s + 'z'

print(b)
# Out:
# helloz

# %%
# Check if something is in string - O(n)
if 'l' in s:
    print(True)
# Out:
# True

# %%
# Accessing specific positions - O(1)

print(s[3])
# Out:
# l

# %%
# Check the length - O(1)

print(len(s))
# Out:
# 5
